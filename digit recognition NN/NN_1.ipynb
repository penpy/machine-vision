# %% [markdown]
# # Neural network with one hidden layer

# %%
from NN_1_hidden_layer import *

# %% [markdown]
# #### Example of trainning images and their labels

# %%
A = np.random.permutation(np.arange(10000))[:40]
for i,idx in enumerate(A):
    plt.subplot(4, 10, i+1)
    plt.imshow(TRAIN_IMAGES[idx], 'Greys')
    plt.axis('off')
    plt.title(str(TRAIN_LABELS[idx]))
plt.show()

# %% [markdown]
# #### Neural network at the beginning of the first training phase

# %%
perf()
# Out:
# Progression:                                      | end
# ...
# Finished.

# %%
nn = NN()
# Untrained neural network nn
nn.accuracy()
# Out:
# 0.1009

# %%
ch = Check(nn)
ch.train_nn()

n_examples = 5
images_ids = np.random.permutation(np.arange(10000))[:n_examples]
for i in range(n_examples):
    ch.example(images_ids[i])
# Out:
# Starting training process...
#       0/3 completed |   |
# Epoch 1/3 completed |=  |
# Epoch 2/3 completed |== |
# Epoch 3/3 completed |===|
# Training process finished.
